# %% [markdown]
# # Silver Orchestration

# %%
dbutils.widgets.text("run_date", "")
run_date = dbutils.widgets.get("run_date")

# Silver Notebook Paths In Order
SILVER_NOTEBOOK = [
  "/Workspace/Users/ghanemkhal@gmail.com/Databricks-Lakehouse-Project/bike_lakehouse_2026/Silver/silver_crm_crust_info",
  "/Workspace/Users/ghanemkhal@gmail.com/Databricks-Lakehouse-Project/bike_lakehouse_2026/Silver/silver_crm_prd_info",
  "/Workspace/Users/ghanemkhal@gmail.com/Databricks-Lakehouse-Project/bike_lakehouse_2026/Silver/silver_crm_sales_details",
  "/Workspace/Users/ghanemkhal@gmail.com/Databricks-Lakehouse-Project/bike_lakehouse_2026/Silver/silver_erp_loc_a101",
  "/Workspace/Users/ghanemkhal@gmail.com/Databricks-Lakehouse-Project/bike_lakehouse_2026/Silver/silver_erp_px_cat_g1v2",
  "/Workspace/Users/ghanemkhal@gmail.com/Databricks-Lakehouse-Project/bike_lakehouse_2026/Silver/erp_customers",
]

# Per-notebook timeout in seconds (0 = no timeout)
TIMEOUT_SECONDS = 0

# Collect (notebook_path, status, output_or_error)
results = []


# Run each Silver notebook in order
for nb in SILVER_NOTEBOOK:
    print(f"\n=== Running Silver notebook: {nb} ===")
    try:
        out = dbutils.notebook.run(
            nb,
            timeout_seconds=TIMEOUT_SECONDS,
            arguments={"run_date": run_date} # downsteam can ignore if unused
        )
        results.append((nb, "SUCESS", out))
        print(f"SUCESS : {nb} | output: {out}")
    except Exception as e:
        results.append((nb, "FAILED", str(e)))
        print(f" FAILED: {nb}\n{e}")
